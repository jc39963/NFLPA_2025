# %%
import pandas as pd
import numpy as np

pd.set_option("mode.copy_on_write", True)

# %%
panel = pd.read_csv("modeling_final.csv")

# %%
panel.head()
# Out:
#    Unnamed: 0     gsis_id display_name  birth_date  height  weight  season  \
# 0           0  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 1           1  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 2           2  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 3           3  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 4           4  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
#
#    week position position_group_y  ...         game_id team  \
# 0   1.0        K             SPEC  ...  2014_01_SF_DAL   SF
# 1   2.0        K             SPEC  ...  2014_02_CHI_SF   SF
# 2   3.0        K             SPEC  ...  2014_03_SF_ARI   SF
# 3   4.0        K             SPEC  ...  2014_04_PHI_SF   SF
# 4   5.0        K             SPEC  ...   2014_05_KC_SF   SF
#
#    report_primary_injury report_status     gameday weekday played  \
# 0                    NaN           NaN  2014-09-07  Sunday   True
# 1                    NaN           NaN  2014-09-14  Sunday   True
# 2                    NaN           NaN  2014-09-21  Sunday   True
# 3                    NaN           NaN  2014-09-28  Sunday   True
# 4                    NaN           NaN  2014-10-05  Sunday   True
#
#   listed_on_report listed_out  missed_due_to_injury
# 0            False      False                 False
# 1            False      False                 False
# 2            False      False                 False
# 3            False      False                 False
# 4            False      False                 False
#
# [5 rows x 23 columns]

# %%
import nflreadpy as nfl

rosters = nfl.load_rosters_weekly([i for i in range(2014, 2026)]).to_pandas()

# %%
rosters.head()
# Out:
#    season team position depth_chart_position jersey_number status  \
# 0    2014   SF        K                 None             9    ACT
# 1    2014   SF        K                 None             9    ACT
# 2    2014   SF        K                 None             9    ACT
# 3    2014   SF        K                 None             9    ACT
# 4    2014   SF        K                 None             9    ACT
#
#      full_name first_name last_name birth_date  ...  game_type  \
# 0  Phil Dawson     Philip    Dawson 1975-01-23  ...        REG
# 1  Phil Dawson     Philip    Dawson 1975-01-23  ...        REG
# 2  Phil Dawson     Philip    Dawson 1975-01-23  ...        REG
# 3  Phil Dawson     Philip    Dawson 1975-01-23  ...        REG
# 4  Phil Dawson     Philip    Dawson 1975-01-23  ...        REG
#
#    status_description_abbr football_name     esb_id gsis_it_id  \
# 0                      A01          Phil  DAW705989      23860
# 1                      A01          Phil  DAW705989      23860
# 2                      A01          Phil  DAW705989      23860
# 3                      A01          Phil  DAW705989      23860
# 4                      A01          Phil  DAW705989      23860
#
#                                smart_id entry_year rookie_year draft_club  \
# 0  32004441-5770-5989-ac23-bf6cdafcb988     1998.0      1998.0       None
# 1  32004441-5770-5989-ac23-bf6cdafcb988     1998.0      1998.0       None
# 2  32004441-5770-5989-ac23-bf6cdafcb988     1998.0      1998.0       None
# 3  32004441-5770-5989-ac23-bf6cdafcb988     1998.0      1998.0       None
# 4  32004441-5770-5989-ac23-bf6cdafcb988     1998.0      1998.0       None
#
#   draft_number
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 36 columns]

# %%
rosters.columns
# Out:
# Index(['season', 'team', 'position', 'depth_chart_position', 'jersey_number',
#        'status', 'full_name', 'first_name', 'last_name', 'birth_date',
#        'height', 'weight', 'college', 'gsis_id', 'espn_id', 'sportradar_id',
#        'yahoo_id', 'rotowire_id', 'pff_id', 'pfr_id', 'fantasy_data_id',
#        'sleeper_id', 'years_exp', 'headshot_url', 'ngs_position', 'week',
#        'game_type', 'status_description_abbr', 'football_name', 'esb_id',
#        'gsis_it_id', 'smart_id', 'entry_year', 'rookie_year', 'draft_club',
#        'draft_number'],
#       dtype='object')

# %%
check = panel.merge(
    rosters[["gsis_id", "season", "week", "status"]],
    how="left",
    on=["gsis_id", "season", "week"],
    indicator=True,
)

# %%
check._merge.value_counts()
# Out:
# _merge
# both          222921
# left_only        246
# right_only         0
# Name: count, dtype: int64

# %%
check.loc[check["_merge"] == "left_only"]
# Out:
#         Unnamed: 0     gsis_id   display_name  birth_date  height  weight  \
# 262            262  00-0019546            NaN         NaN     NaN     NaN
# 785            785  00-0020578    Matt Bryant  1975-05-29    69.0   203.0
# 945            945  00-0020972  Billy Cundiff  1980-03-30    73.0   212.0
# 1342          1342  00-0021678      Tony Romo  1980-04-21    74.0   230.0
# 1512          1512  00-0022017            NaN         NaN     NaN     NaN
# ...            ...         ...            ...         ...     ...     ...
# 106549      104981  00-0032189   Tony Steward  1992-09-19    72.0   241.0
# 107065      105497  00-0032205            NaN         NaN     NaN     NaN
# 109237      107669  00-0032265  Mario Edwards  1994-01-25    75.0   280.0
# 109523      107955  00-0032271   D'Joun Smith  1992-09-23    71.0   193.0
# 109528      107960  00-0032271   D'Joun Smith  1992-09-23    71.0   193.0
#
#         season  week position position_group_y  ... report_primary_injury  \
# 262     2014.0   3.0      NaN              NaN  ...                   NaN
# 785     2015.0  14.0        K             SPEC  ...       right Quadricep
# 945     2014.0  15.0        K             SPEC  ...            right Knee
# 1342    2015.0  16.0       QB               QB  ...         left Shoulder
# 1512    2014.0  17.0      NaN              NaN  ...              Shoulder
# ...        ...   ...      ...              ...  ...                   ...
# 106549  2015.0  14.0       LB               LB  ...                   NaN
# 107065  2015.0  14.0      NaN              NaN  ...                  Knee
# 109237  2015.0  16.0      NaN              NaN  ...                  Neck
# 109523  2015.0   2.0       CB               DB  ...                   NaN
# 109528  2015.0  16.0       CB               DB  ...                   NaN
#
#        report_status  gameday weekday played listed_on_report listed_out  \
# 262              NaN      NaN     NaN  False            False      False
# 785              Out      NaN     NaN  False             True       True
# 945     Questionable      NaN     NaN  False             True       True
# 1342             Out      NaN     NaN  False             True       True
# 1512             Out      NaN     NaN  False             True       True
# ...              ...      ...     ...    ...              ...        ...
# 106549           NaN      NaN     NaN  False            False      False
# 107065           Out      NaN     NaN  False             True       True
# 109237           Out      NaN     NaN  False             True       True
# 109523           NaN      NaN     NaN  False            False      False
# 109528           NaN      NaN     NaN  False            False      False
#
#        missed_due_to_injury status     _merge
# 262                   False    NaN  left_only
# 785                    True    NaN  left_only
# 945                    True    NaN  left_only
# 1342                   True    NaN  left_only
# 1512                   True    NaN  left_only
# ...                     ...    ...        ...
# 106549                False    NaN  left_only
# 107065                 True    NaN  left_only
# 109237                 True    NaN  left_only
# 109523                False    NaN  left_only
# 109528                False    NaN  left_only
#
# [246 rows x 25 columns]

# %%
# just drop those 246 entries who had injury/other data but not roster data for now?
# note somewhere that we only our player-week panel only includes ppl who were on weekly rosters
final = check.loc[check["_merge"] == "both"]

# %%
# just confirming that gsis_id is consistent across seasons
final.loc[(final["display_name"] == "Tony Romo")].sort_values(by="week")
# Out:
#       Unnamed: 0     gsis_id display_name  birth_date  height  weight  season  \
# 1317        1317  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1343        1343  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1335        1335  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1318        1318  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1344        1344  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1336        1336  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1319        1319  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1345        1345  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1320        1320  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1346        1346  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1321        1321  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1347        1347  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1322        1322  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1348        1348  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1323        1323  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1349        1349  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1324        1324  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1350        1350  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1325        1325  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1326        1326  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1351        1351  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1352        1352  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1337        1337  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1338        1338  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1327        1327  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1339        1339  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1328        1328  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1329        1329  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1340        1340  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1330        1330  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1341        1341  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2015.0
# 1331        1331  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1353        1353  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2016.0
# 1332        1332  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1333        1333  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
# 1334        1334  00-0021678    Tony Romo  1980-04-21    74.0   230.0  2014.0
#
#       week position position_group_y  ... report_primary_injury report_status  \
# 1317   1.0       QB               QB  ...                  Back      Probable
# 1343   1.0       QB               QB  ...                  Back           Out
# 1335   1.0       QB               QB  ...                  Back      Probable
# 1318   2.0       QB               QB  ...                  Back      Probable
# 1344   2.0       QB               QB  ...                  Back           Out
# 1336   2.0       QB               QB  ...                  Back      Probable
# 1319   3.0       QB               QB  ...                  Back      Probable
# 1345   3.0       QB               QB  ...                  Back           Out
# 1320   4.0       QB               QB  ...                  Back      Probable
# 1346   4.0       QB               QB  ...                  Back           Out
# 1321   5.0       QB               QB  ...                  Back      Probable
# 1347   5.0       QB               QB  ...                  Back           Out
# 1322   6.0       QB               QB  ...                  Back      Probable
# 1348   6.0       QB               QB  ...                  Back           Out
# 1323   7.0       QB               QB  ...                  Back      Probable
# 1349   8.0       QB               QB  ...                  Back           Out
# 1324   8.0       QB               QB  ...                  Back      Probable
# 1350   9.0       QB               QB  ...                  Back           Out
# 1325   9.0       QB               QB  ...                  Back  Questionable
# 1326  10.0       QB               QB  ...                  Back      Probable
# 1351  10.0       QB               QB  ...                  Back  Questionable
# 1352  11.0       QB               QB  ...                  Back  Questionable
# 1337  11.0       QB               QB  ...                   NaN           NaN
# 1338  12.0       QB               QB  ...                  Back      Probable
# 1327  12.0       QB               QB  ...                  Back      Probable
# 1339  13.0       QB               QB  ...         left Shoulder           Out
# 1328  13.0       QB               QB  ...                  Back      Probable
# 1329  14.0       QB               QB  ...                  Back      Probable
# 1340  14.0       QB               QB  ...         left Shoulder           Out
# 1330  15.0       QB               QB  ...                  Back      Probable
# 1341  15.0       QB               QB  ...         left Shoulder           Out
# 1331  16.0       QB               QB  ...                  Back      Probable
# 1353  17.0       QB               QB  ...                   NaN           NaN
# 1332  17.0       QB               QB  ...                  Back      Probable
# 1333  18.0       QB               QB  ...                  Back      Probable
# 1334  19.0       QB               QB  ...                  Back      Probable
#
#          gameday   weekday played listed_on_report listed_out  \
# 1317  2014-09-07    Sunday   True             True       True
# 1343         NaN       NaN  False             True       True
# 1335  2015-09-13    Sunday   True             True       True
# 1318  2014-09-14    Sunday   True             True       True
# 1344         NaN       NaN  False             True       True
# 1336  2015-09-20    Sunday   True             True       True
# 1319  2014-09-21    Sunday   True             True       True
# 1345         NaN       NaN  False             True       True
# 1320  2014-09-28    Sunday   True             True       True
# 1346         NaN       NaN  False             True       True
# 1321  2014-10-05    Sunday   True             True       True
# 1347         NaN       NaN  False             True       True
# 1322  2014-10-12    Sunday   True             True       True
# 1348         NaN       NaN  False             True       True
# 1323  2014-10-19    Sunday   True             True       True
# 1349         NaN       NaN  False             True       True
# 1324  2014-10-27    Monday   True             True       True
# 1350         NaN       NaN  False             True       True
# 1325         NaN       NaN  False             True       True
# 1326  2014-11-09    Sunday   True             True       True
# 1351         NaN       NaN  False             True       True
# 1352         NaN       NaN  False             True       True
# 1337  2015-11-22    Sunday   True            False      False
# 1338  2015-11-26  Thursday   True             True       True
# 1327  2014-11-23    Sunday   True             True       True
# 1339         NaN       NaN  False             True       True
# 1328  2014-11-27  Thursday   True             True       True
# 1329  2014-12-04  Thursday   True             True       True
# 1340         NaN       NaN  False             True       True
# 1330  2014-12-14    Sunday   True             True       True
# 1341         NaN       NaN  False             True       True
# 1331  2014-12-21    Sunday   True             True       True
# 1353  2017-01-01    Sunday   True            False      False
# 1332  2014-12-28    Sunday   True             True       True
# 1333  2015-01-04    Sunday   True             True       True
# 1334  2015-01-11    Sunday   True             True       True
#
#      missed_due_to_injury status  _merge
# 1317                False    ACT    both
# 1343                 True    ACT    both
# 1335                False    RES    both
# 1318                False    ACT    both
# 1344                 True    ACT    both
# 1336                False    RES    both
# 1319                False    ACT    both
# 1345                 True    ACT    both
# 1320                False    ACT    both
# 1346                 True    ACT    both
# 1321                False    ACT    both
# 1347                 True    ACT    both
# 1322                False    ACT    both
# 1348                 True    ACT    both
# 1323                False    ACT    both
# 1349                 True    ACT    both
# 1324                False    ACT    both
# 1350                 True    ACT    both
# 1325                 True    ACT    both
# 1326                False    ACT    both
# 1351                 True    ACT    both
# 1352                 True    ACT    both
# 1337                False    RES    both
# 1338                False    RES    both
# 1327                False    ACT    both
# 1339                 True    RES    both
# 1328                False    ACT    both
# 1329                False    ACT    both
# 1340                 True    RES    both
# 1330                False    ACT    both
# 1341                 True    RES    both
# 1331                False    ACT    both
# 1353                False    ACT    both
# 1332                False    ACT    both
# 1333                False    ACT    both
# 1334                False    ACT    both
#
# [36 rows x 25 columns]

# %%
# create binary column for whether a given week is a return week (from injury) for a player
# using only the missed due to injury column for this because that already considers both injury report & snap count

final_sorted = final.sort_values(by=["gsis_id", "season", "week"])
final_sorted["is_return_week"] = (
    (final_sorted["missed_due_to_injury"] == False) & (final_sorted["played"])
) & (
    (
        final_sorted.groupby(by=["gsis_id", "season"])["missed_due_to_injury"].shift(
            fill_value=False
        )
    )
    | (
        final_sorted.groupby(by=["gsis_id", "season"])["played"].shift(fill_value=True)
        == False
    )
)

# %%
# final_sorted = final.sort_values(by=["gsis_id", "season", "week"])
# final_sorted["is_return_week"] = (final_sorted["status"] == "ACT") & (
#     final_sorted.groupby(by=["gsis_id", "season"])["status"].shift(fill_value="ACT")
#     != "ACT"
# )

# %%
final_sorted["return_week"] = final_sorted["week"].where(final_sorted["is_return_week"])

# %%
final_sorted["return_week"] = final_sorted.groupby(by=["gsis_id", "season"])[
    "return_week"
].ffill()

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2021)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201180      199600  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201181      199601  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201182      199602  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201183      199603  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201184      199604  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201185      199605  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201186      199606  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201187      199607  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201188      199608  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201189      199609  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201190      199610  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201191      199611  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201192      199612  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201193      199613  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201194      199614  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ...     gameday weekday  \
# 201180  2021.0   1.0       WR               WR  ...  2021-09-12  Sunday
# 201181  2021.0   3.0       WR               WR  ...  2021-09-26  Sunday
# 201182  2021.0   4.0       WR               WR  ...  2021-10-03  Sunday
# 201183  2021.0   5.0       WR               WR  ...  2021-10-10  Sunday
# 201184  2021.0   6.0       WR               WR  ...  2021-10-17  Sunday
# 201185  2021.0   7.0       WR               WR  ...         NaN     NaN
# 201186  2021.0   8.0       WR               WR  ...  2021-11-01  Monday
# 201187  2021.0   9.0       WR               WR  ...  2021-11-07  Sunday
# 201188  2021.0  11.0       WR               WR  ...  2021-11-22  Monday
# 201189  2021.0  12.0       WR               WR  ...         NaN     NaN
# 201190  2021.0  13.0       WR               WR  ...         NaN     NaN
# 201191  2021.0  14.0       WR               WR  ...         NaN     NaN
# 201192  2021.0  16.0       WR               WR  ...  2021-12-26  Sunday
# 201193  2021.0  17.0       WR               WR  ...         NaN     NaN
# 201194  2021.0  18.0       WR               WR  ...         NaN     NaN
#
#         played listed_on_report listed_out missed_due_to_injury status _merge  \
# 201180    True            False      False                False    ACT   both
# 201181    True            False      False                False    ACT   both
# 201182    True            False      False                False    ACT   both
# 201183    True            False      False                False    ACT   both
# 201184    True             True       True                False    ACT   both
# 201185   False             True       True                 True    INA   both
# 201186    True             True       True                False    ACT   both
# 201187    True            False      False                False    ACT   both
# 201188    True            False      False                False    ACT   both
# 201189   False             True       True                 True    INA   both
# 201190   False             True       True                 True    INA   both
# 201191   False             True       True                 True    INA   both
# 201192    True             True       True                False    ACT   both
# 201193   False             True       True                 True    INA   both
# 201194   False             True       True                 True    INA   both
#
#        is_return_week  return_week
# 201180          False          NaN
# 201181          False          NaN
# 201182          False          NaN
# 201183          False          NaN
# 201184          False          NaN
# 201185          False          NaN
# 201186           True          8.0
# 201187          False          8.0
# 201188          False          8.0
# 201189          False          8.0
# 201190          False          8.0
# 201191          False          8.0
# 201192           True         16.0
# 201193          False         16.0
# 201194          False         16.0
#
# [15 rows x 27 columns]

# %%
final_sorted.loc[final_sorted["missed_due_to_injury"], "return_week"] = None

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2021)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201180      199600  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201181      199601  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201182      199602  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201183      199603  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201184      199604  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201185      199605  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201186      199606  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201187      199607  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201188      199608  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201189      199609  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201190      199610  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201191      199611  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201192      199612  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201193      199613  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201194      199614  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ...     gameday weekday  \
# 201180  2021.0   1.0       WR               WR  ...  2021-09-12  Sunday
# 201181  2021.0   3.0       WR               WR  ...  2021-09-26  Sunday
# 201182  2021.0   4.0       WR               WR  ...  2021-10-03  Sunday
# 201183  2021.0   5.0       WR               WR  ...  2021-10-10  Sunday
# 201184  2021.0   6.0       WR               WR  ...  2021-10-17  Sunday
# 201185  2021.0   7.0       WR               WR  ...         NaN     NaN
# 201186  2021.0   8.0       WR               WR  ...  2021-11-01  Monday
# 201187  2021.0   9.0       WR               WR  ...  2021-11-07  Sunday
# 201188  2021.0  11.0       WR               WR  ...  2021-11-22  Monday
# 201189  2021.0  12.0       WR               WR  ...         NaN     NaN
# 201190  2021.0  13.0       WR               WR  ...         NaN     NaN
# 201191  2021.0  14.0       WR               WR  ...         NaN     NaN
# 201192  2021.0  16.0       WR               WR  ...  2021-12-26  Sunday
# 201193  2021.0  17.0       WR               WR  ...         NaN     NaN
# 201194  2021.0  18.0       WR               WR  ...         NaN     NaN
#
#         played listed_on_report listed_out missed_due_to_injury status _merge  \
# 201180    True            False      False                False    ACT   both
# 201181    True            False      False                False    ACT   both
# 201182    True            False      False                False    ACT   both
# 201183    True            False      False                False    ACT   both
# 201184    True             True       True                False    ACT   both
# 201185   False             True       True                 True    INA   both
# 201186    True             True       True                False    ACT   both
# 201187    True            False      False                False    ACT   both
# 201188    True            False      False                False    ACT   both
# 201189   False             True       True                 True    INA   both
# 201190   False             True       True                 True    INA   both
# 201191   False             True       True                 True    INA   both
# 201192    True             True       True                False    ACT   both
# 201193   False             True       True                 True    INA   both
# 201194   False             True       True                 True    INA   both
#
#        is_return_week  return_week
# 201180          False          NaN
# 201181          False          NaN
# 201182          False          NaN
# 201183          False          NaN
# 201184          False          NaN
# 201185          False          NaN
# 201186           True          8.0
# 201187          False          8.0
# 201188          False          8.0
# 201189          False          NaN
# 201190          False          NaN
# 201191          False          NaN
# 201192           True         16.0
# 201193          False          NaN
# 201194          False          NaN
#
# [15 rows x 27 columns]

# %%
final_sorted["weeks_since_return"] = final_sorted["week"] - final_sorted["return_week"]

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201195      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201196      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201197      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201198      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201199      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201200      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201201      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201202      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201203      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201204      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201205      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201206      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201207      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201208      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201209      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201210      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201211      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201212      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201213      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201214      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201215      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ...   weekday played  \
# 201195  2022.0   1.0       WR               WR  ...    Sunday   True
# 201196  2022.0   2.0       WR               WR  ...    Sunday   True
# 201197  2022.0   3.0       WR               WR  ...       NaN  False
# 201198  2022.0   4.0       WR               WR  ...       NaN  False
# 201199  2022.0   5.0       WR               WR  ...       NaN  False
# 201200  2022.0   6.0       WR               WR  ...       NaN  False
# 201201  2022.0   7.0       WR               WR  ...       NaN  False
# 201202  2022.0   8.0       WR               WR  ...       NaN  False
# 201203  2022.0   9.0       WR               WR  ...    Sunday   True
# 201204  2022.0  10.0       WR               WR  ...    Sunday   True
# 201205  2022.0  11.0       WR               WR  ...    Sunday   True
# 201206  2022.0  12.0       WR               WR  ...       NaN  False
# 201207  2022.0  13.0       WR               WR  ...       NaN  False
# 201208  2022.0  14.0       WR               WR  ...       NaN  False
# 201209  2022.0  15.0       WR               WR  ...    Sunday   True
# 201210  2022.0  16.0       WR               WR  ...  Saturday   True
# 201211  2022.0  17.0       WR               WR  ...    Sunday   True
# 201212  2022.0  18.0       WR               WR  ...  Saturday   True
# 201213  2022.0  20.0       WR               WR  ...  Saturday   True
# 201214  2022.0  21.0       WR               WR  ...    Sunday   True
# 201215  2022.0  22.0       WR               WR  ...    Sunday   True
#
#         listed_on_report listed_out missed_due_to_injury status _merge  \
# 201195             False      False                False    ACT   both
# 201196              True       True                False    ACT   both
# 201197              True       True                 True    INA   both
# 201198              True       True                 True    INA   both
# 201199              True       True                 True    INA   both
# 201200              True       True                 True    INA   both
# 201201              True       True                 True    INA   both
# 201202             False      False                False    CUT   both
# 201203             False      False                False    ACT   both
# 201204             False      False                False    ACT   both
# 201205             False      False                False    ACT   both
# 201206              True       True                 True    INA   both
# 201207              True       True                 True    INA   both
# 201208              True       True                 True    INA   both
# 201209              True       True                False    ACT   both
# 201210             False      False                False    ACT   both
# 201211             False      False                False    ACT   both
# 201212             False      False                False    ACT   both
# 201213             False      False                False    ACT   both
# 201214             False      False                False    ACT   both
# 201215             False      False                False    ACT   both
#
#        is_return_week return_week  weeks_since_return
# 201195          False         NaN                 NaN
# 201196          False         NaN                 NaN
# 201197          False         NaN                 NaN
# 201198          False         NaN                 NaN
# 201199          False         NaN                 NaN
# 201200          False         NaN                 NaN
# 201201          False         NaN                 NaN
# 201202          False         NaN                 NaN
# 201203           True         9.0                 0.0
# 201204          False         9.0                 1.0
# 201205          False         9.0                 2.0
# 201206          False         NaN                 NaN
# 201207          False         NaN                 NaN
# 201208          False         NaN                 NaN
# 201209           True        15.0                 0.0
# 201210          False        15.0                 1.0
# 201211          False        15.0                 2.0
# 201212          False        15.0                 3.0
# 201213          False        15.0                 5.0
# 201214          False        15.0                 6.0
# 201215          False        15.0                 7.0
#
# [21 rows x 28 columns]

# %%
final_sorted["is_injury_start"] = (final_sorted["missed_due_to_injury"] == True) & (
    final_sorted.groupby(by=["gsis_id", "season"])["missed_due_to_injury"].shift(
        fill_value=False
    )
    == False
)

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201195      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201196      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201197      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201198      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201199      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201200      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201201      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201202      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201203      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201204      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201205      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201206      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201207      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201208      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201209      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201210      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201211      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201212      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201213      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201214      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201215      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... played listed_on_report  \
# 201195  2022.0   1.0       WR               WR  ...   True            False
# 201196  2022.0   2.0       WR               WR  ...   True             True
# 201197  2022.0   3.0       WR               WR  ...  False             True
# 201198  2022.0   4.0       WR               WR  ...  False             True
# 201199  2022.0   5.0       WR               WR  ...  False             True
# 201200  2022.0   6.0       WR               WR  ...  False             True
# 201201  2022.0   7.0       WR               WR  ...  False             True
# 201202  2022.0   8.0       WR               WR  ...  False            False
# 201203  2022.0   9.0       WR               WR  ...   True            False
# 201204  2022.0  10.0       WR               WR  ...   True            False
# 201205  2022.0  11.0       WR               WR  ...   True            False
# 201206  2022.0  12.0       WR               WR  ...  False             True
# 201207  2022.0  13.0       WR               WR  ...  False             True
# 201208  2022.0  14.0       WR               WR  ...  False             True
# 201209  2022.0  15.0       WR               WR  ...   True             True
# 201210  2022.0  16.0       WR               WR  ...   True            False
# 201211  2022.0  17.0       WR               WR  ...   True            False
# 201212  2022.0  18.0       WR               WR  ...   True            False
# 201213  2022.0  20.0       WR               WR  ...   True            False
# 201214  2022.0  21.0       WR               WR  ...   True            False
# 201215  2022.0  22.0       WR               WR  ...   True            False
#
#         listed_out missed_due_to_injury status _merge is_return_week  \
# 201195       False                False    ACT   both          False
# 201196        True                False    ACT   both          False
# 201197        True                 True    INA   both          False
# 201198        True                 True    INA   both          False
# 201199        True                 True    INA   both          False
# 201200        True                 True    INA   both          False
# 201201        True                 True    INA   both          False
# 201202       False                False    CUT   both          False
# 201203       False                False    ACT   both           True
# 201204       False                False    ACT   both          False
# 201205       False                False    ACT   both          False
# 201206        True                 True    INA   both          False
# 201207        True                 True    INA   both          False
# 201208        True                 True    INA   both          False
# 201209        True                False    ACT   both           True
# 201210       False                False    ACT   both          False
# 201211       False                False    ACT   both          False
# 201212       False                False    ACT   both          False
# 201213       False                False    ACT   both          False
# 201214       False                False    ACT   both          False
# 201215       False                False    ACT   both          False
#
#        return_week weeks_since_return  is_injury_start
# 201195         NaN                NaN            False
# 201196         NaN                NaN            False
# 201197         NaN                NaN             True
# 201198         NaN                NaN            False
# 201199         NaN                NaN            False
# 201200         NaN                NaN            False
# 201201         NaN                NaN            False
# 201202         NaN                NaN            False
# 201203         9.0                0.0            False
# 201204         9.0                1.0            False
# 201205         9.0                2.0            False
# 201206         NaN                NaN             True
# 201207         NaN                NaN            False
# 201208         NaN                NaN            False
# 201209        15.0                0.0            False
# 201210        15.0                1.0            False
# 201211        15.0                2.0            False
# 201212        15.0                3.0            False
# 201213        15.0                5.0            False
# 201214        15.0                6.0            False
# 201215        15.0                7.0            False
#
# [21 rows x 29 columns]

# %%
final_sorted["total_injuries_current_season"] = final_sorted.groupby(
    by=["gsis_id", "season"]
)["is_injury_start"].cumsum()

# %%
final_sorted["total_injuries_current_season"] = final_sorted.groupby(
    by=["gsis_id", "season"]
)["total_injuries_current_season"].shift(fill_value=0)

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201195      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201196      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201197      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201198      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201199      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201200      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201201      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201202      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201203      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201204      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201205      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201206      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201207      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201208      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201209      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201210      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201211      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201212      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201213      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201214      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201215      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... listed_on_report  \
# 201195  2022.0   1.0       WR               WR  ...            False
# 201196  2022.0   2.0       WR               WR  ...             True
# 201197  2022.0   3.0       WR               WR  ...             True
# 201198  2022.0   4.0       WR               WR  ...             True
# 201199  2022.0   5.0       WR               WR  ...             True
# 201200  2022.0   6.0       WR               WR  ...             True
# 201201  2022.0   7.0       WR               WR  ...             True
# 201202  2022.0   8.0       WR               WR  ...            False
# 201203  2022.0   9.0       WR               WR  ...            False
# 201204  2022.0  10.0       WR               WR  ...            False
# 201205  2022.0  11.0       WR               WR  ...            False
# 201206  2022.0  12.0       WR               WR  ...             True
# 201207  2022.0  13.0       WR               WR  ...             True
# 201208  2022.0  14.0       WR               WR  ...             True
# 201209  2022.0  15.0       WR               WR  ...             True
# 201210  2022.0  16.0       WR               WR  ...            False
# 201211  2022.0  17.0       WR               WR  ...            False
# 201212  2022.0  18.0       WR               WR  ...            False
# 201213  2022.0  20.0       WR               WR  ...            False
# 201214  2022.0  21.0       WR               WR  ...            False
# 201215  2022.0  22.0       WR               WR  ...            False
#
#        listed_out  missed_due_to_injury status _merge is_return_week  \
# 201195      False                 False    ACT   both          False
# 201196       True                 False    ACT   both          False
# 201197       True                  True    INA   both          False
# 201198       True                  True    INA   both          False
# 201199       True                  True    INA   both          False
# 201200       True                  True    INA   both          False
# 201201       True                  True    INA   both          False
# 201202      False                 False    CUT   both          False
# 201203      False                 False    ACT   both           True
# 201204      False                 False    ACT   both          False
# 201205      False                 False    ACT   both          False
# 201206       True                  True    INA   both          False
# 201207       True                  True    INA   both          False
# 201208       True                  True    INA   both          False
# 201209       True                 False    ACT   both           True
# 201210      False                 False    ACT   both          False
# 201211      False                 False    ACT   both          False
# 201212      False                 False    ACT   both          False
# 201213      False                 False    ACT   both          False
# 201214      False                 False    ACT   both          False
# 201215      False                 False    ACT   both          False
#
#        return_week weeks_since_return is_injury_start  \
# 201195         NaN                NaN           False
# 201196         NaN                NaN           False
# 201197         NaN                NaN            True
# 201198         NaN                NaN           False
# 201199         NaN                NaN           False
# 201200         NaN                NaN           False
# 201201         NaN                NaN           False
# 201202         NaN                NaN           False
# 201203         9.0                0.0           False
# 201204         9.0                1.0           False
# 201205         9.0                2.0           False
# 201206         NaN                NaN            True
# 201207         NaN                NaN           False
# 201208         NaN                NaN           False
# 201209        15.0                0.0           False
# 201210        15.0                1.0           False
# 201211        15.0                2.0           False
# 201212        15.0                3.0           False
# 201213        15.0                5.0           False
# 201214        15.0                6.0           False
# 201215        15.0                7.0           False
#
#         total_injuries_current_season
# 201195                              0
# 201196                              0
# 201197                              0
# 201198                              1
# 201199                              1
# 201200                              1
# 201201                              1
# 201202                              1
# 201203                              1
# 201204                              1
# 201205                              1
# 201206                              1
# 201207                              2
# 201208                              2
# 201209                              2
# 201210                              2
# 201211                              2
# 201212                              2
# 201213                              2
# 201214                              2
# 201215                              2
#
# [21 rows x 30 columns]

# %%
# this we prob don't need since we only have 2014 onwards data oops

# final_sorted["total_injuries_career"] = final_sorted.groupby(by=["gsis_id"])[
#     "is_injury_start"
# ].cumsum()

# %%
# final_sorted["total_injuries_career"] = final_sorted.groupby(by=["gsis_id"])[
#     "total_injuries_career"
# ].shift(fill_value=0)

# %%
final_sorted["player_age"] = (
    pd.to_datetime(final_sorted["gameday"], format="%Y-%m-%d")
    - pd.to_datetime(final_sorted["birth_date"], format="%Y-%m-%d")
).dt.total_seconds()

# %%
final_sorted["player_age"] = np.floor((final_sorted["player_age"] / 3600 / 24 / 365.25))

# %%
final_sorted["player_age"] = final_sorted.groupby(by=["gsis_id", "season"])[
    "player_age"
].transform(lambda x: x.ffill().bfill())

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201195      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201196      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201197      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201198      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201199      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201200      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201201      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201202      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201203      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201204      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201205      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201206      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201207      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201208      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201209      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201210      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201211      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201212      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201213      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201214      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201215      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... listed_out  \
# 201195  2022.0   1.0       WR               WR  ...      False
# 201196  2022.0   2.0       WR               WR  ...       True
# 201197  2022.0   3.0       WR               WR  ...       True
# 201198  2022.0   4.0       WR               WR  ...       True
# 201199  2022.0   5.0       WR               WR  ...       True
# 201200  2022.0   6.0       WR               WR  ...       True
# 201201  2022.0   7.0       WR               WR  ...       True
# 201202  2022.0   8.0       WR               WR  ...      False
# 201203  2022.0   9.0       WR               WR  ...      False
# 201204  2022.0  10.0       WR               WR  ...      False
# 201205  2022.0  11.0       WR               WR  ...      False
# 201206  2022.0  12.0       WR               WR  ...       True
# 201207  2022.0  13.0       WR               WR  ...       True
# 201208  2022.0  14.0       WR               WR  ...       True
# 201209  2022.0  15.0       WR               WR  ...       True
# 201210  2022.0  16.0       WR               WR  ...      False
# 201211  2022.0  17.0       WR               WR  ...      False
# 201212  2022.0  18.0       WR               WR  ...      False
# 201213  2022.0  20.0       WR               WR  ...      False
# 201214  2022.0  21.0       WR               WR  ...      False
# 201215  2022.0  22.0       WR               WR  ...      False
#
#        missed_due_to_injury  status _merge is_return_week return_week  \
# 201195                False     ACT   both          False         NaN
# 201196                False     ACT   both          False         NaN
# 201197                 True     INA   both          False         NaN
# 201198                 True     INA   both          False         NaN
# 201199                 True     INA   both          False         NaN
# 201200                 True     INA   both          False         NaN
# 201201                 True     INA   both          False         NaN
# 201202                False     CUT   both          False         NaN
# 201203                False     ACT   both           True         9.0
# 201204                False     ACT   both          False         9.0
# 201205                False     ACT   both          False         9.0
# 201206                 True     INA   both          False         NaN
# 201207                 True     INA   both          False         NaN
# 201208                 True     INA   both          False         NaN
# 201209                False     ACT   both           True        15.0
# 201210                False     ACT   both          False        15.0
# 201211                False     ACT   both          False        15.0
# 201212                False     ACT   both          False        15.0
# 201213                False     ACT   both          False        15.0
# 201214                False     ACT   both          False        15.0
# 201215                False     ACT   both          False        15.0
#
#        weeks_since_return is_injury_start total_injuries_current_season  \
# 201195                NaN           False                             0
# 201196                NaN           False                             0
# 201197                NaN            True                             0
# 201198                NaN           False                             1
# 201199                NaN           False                             1
# 201200                NaN           False                             1
# 201201                NaN           False                             1
# 201202                NaN           False                             1
# 201203                0.0           False                             1
# 201204                1.0           False                             1
# 201205                2.0           False                             1
# 201206                NaN            True                             1
# 201207                NaN           False                             2
# 201208                NaN           False                             2
# 201209                0.0           False                             2
# 201210                1.0           False                             2
# 201211                2.0           False                             2
# 201212                3.0           False                             2
# 201213                5.0           False                             2
# 201214                6.0           False                             2
# 201215                7.0           False                             2
#
#         player_age
# 201195        23.0
# 201196        23.0
# 201197        23.0
# 201198        23.0
# 201199        23.0
# 201200        23.0
# 201201        23.0
# 201202        23.0
# 201203        23.0
# 201204        23.0
# 201205        23.0
# 201206        23.0
# 201207        23.0
# 201208        23.0
# 201209        23.0
# 201210        23.0
# 201211        23.0
# 201212        23.0
# 201213        23.0
# 201214        24.0
# 201215        24.0
#
# [21 rows x 31 columns]

# %%
final_sorted["gameday"] = pd.to_datetime(final_sorted["gameday"])

final_sorted["rest_days_since_last_play"] = (
    final_sorted["gameday"] - final_sorted["gameday"].ffill().shift()
).dt.days

# %%
final_sorted.loc[
    (final_sorted["display_name"] == "Kadarius Toney")
    & (final_sorted["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 201195      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201196      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201197      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201198      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201199      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201200      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201201      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201202      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201203      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201204      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201205      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201206      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201207      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201208      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201209      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201210      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201211      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201212      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201213      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201214      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 201215      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... missed_due_to_injury  \
# 201195  2022.0   1.0       WR               WR  ...                False
# 201196  2022.0   2.0       WR               WR  ...                False
# 201197  2022.0   3.0       WR               WR  ...                 True
# 201198  2022.0   4.0       WR               WR  ...                 True
# 201199  2022.0   5.0       WR               WR  ...                 True
# 201200  2022.0   6.0       WR               WR  ...                 True
# 201201  2022.0   7.0       WR               WR  ...                 True
# 201202  2022.0   8.0       WR               WR  ...                False
# 201203  2022.0   9.0       WR               WR  ...                False
# 201204  2022.0  10.0       WR               WR  ...                False
# 201205  2022.0  11.0       WR               WR  ...                False
# 201206  2022.0  12.0       WR               WR  ...                 True
# 201207  2022.0  13.0       WR               WR  ...                 True
# 201208  2022.0  14.0       WR               WR  ...                 True
# 201209  2022.0  15.0       WR               WR  ...                False
# 201210  2022.0  16.0       WR               WR  ...                False
# 201211  2022.0  17.0       WR               WR  ...                False
# 201212  2022.0  18.0       WR               WR  ...                False
# 201213  2022.0  20.0       WR               WR  ...                False
# 201214  2022.0  21.0       WR               WR  ...                False
# 201215  2022.0  22.0       WR               WR  ...                False
#
#        status  _merge is_return_week return_week weeks_since_return  \
# 201195    ACT    both          False         NaN                NaN
# 201196    ACT    both          False         NaN                NaN
# 201197    INA    both          False         NaN                NaN
# 201198    INA    both          False         NaN                NaN
# 201199    INA    both          False         NaN                NaN
# 201200    INA    both          False         NaN                NaN
# 201201    INA    both          False         NaN                NaN
# 201202    CUT    both          False         NaN                NaN
# 201203    ACT    both           True         9.0                0.0
# 201204    ACT    both          False         9.0                1.0
# 201205    ACT    both          False         9.0                2.0
# 201206    INA    both          False         NaN                NaN
# 201207    INA    both          False         NaN                NaN
# 201208    INA    both          False         NaN                NaN
# 201209    ACT    both           True        15.0                0.0
# 201210    ACT    both          False        15.0                1.0
# 201211    ACT    both          False        15.0                2.0
# 201212    ACT    both          False        15.0                3.0
# 201213    ACT    both          False        15.0                5.0
# 201214    ACT    both          False        15.0                6.0
# 201215    ACT    both          False        15.0                7.0
#
#        is_injury_start total_injuries_current_season player_age  \
# 201195           False                             0       23.0
# 201196           False                             0       23.0
# 201197            True                             0       23.0
# 201198           False                             1       23.0
# 201199           False                             1       23.0
# 201200           False                             1       23.0
# 201201           False                             1       23.0
# 201202           False                             1       23.0
# 201203           False                             1       23.0
# 201204           False                             1       23.0
# 201205           False                             1       23.0
# 201206            True                             1       23.0
# 201207           False                             2       23.0
# 201208           False                             2       23.0
# 201209           False                             2       23.0
# 201210           False                             2       23.0
# 201211           False                             2       23.0
# 201212           False                             2       23.0
# 201213           False                             2       23.0
# 201214           False                             2       24.0
# 201215           False                             2       24.0
#
#         rest_days_since_last_play
# 201195                      259.0
# 201196                        7.0
# 201197                        NaN
# 201198                        NaN
# 201199                        NaN
# 201200                        NaN
# 201201                        NaN
# 201202                        NaN
# 201203                       49.0
# 201204                        7.0
# 201205                        7.0
# 201206                        NaN
# 201207                        NaN
# 201208                        NaN
# 201209                       28.0
# 201210                        6.0
# 201211                        8.0
# 201212                        6.0
# 201213                       14.0
# 201214                        8.0
# 201215                       14.0
#
# [21 rows x 32 columns]

# %%
sched = nfl.load_schedules().to_pandas()[["game_id", "surface"]]

# %%
surf = final_sorted.drop("_merge", axis=1).merge(
    sched, how="left", on="game_id", indicator=True
)

# %%
surf._merge.value_counts()
# Out:
# _merge
# both          193181
# left_only      29740
# right_only         0
# Name: count, dtype: int64

# %%
# confirming that left only rows are from cases where the player didn't play (so we don't care abt surface)
surf.loc[(surf["played"] == True) & (surf["_merge"] == "left_only")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, gsis_id, display_name, birth_date, height, weight, season, week, position, position_group_y, season_type, opponent, total_snaps, game_id, team, report_primary_injury, report_status, gameday, weekday, played, listed_on_report, listed_out, missed_due_to_injury, status, is_return_week, return_week, weeks_since_return, is_injury_start, total_injuries_current_season, player_age, rest_days_since_last_play, surface, _merge]
# Index: []
#
# [0 rows x 33 columns]

# %%
surf.head()
# Out:
#    Unnamed: 0     gsis_id display_name  birth_date  height  weight  season  \
# 0           0  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 1           1  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 2           2  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 3           3  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
# 4           4  00-0004091  Phil Dawson  1975-01-23    71.0   200.0  2014.0
#
#    week position position_group_y  ... status is_return_week  return_week  \
# 0   1.0        K             SPEC  ...    ACT          False          NaN
# 1   2.0        K             SPEC  ...    ACT          False          NaN
# 2   3.0        K             SPEC  ...    ACT          False          NaN
# 3   4.0        K             SPEC  ...    ACT          False          NaN
# 4   5.0        K             SPEC  ...    ACT          False          NaN
#
#   weeks_since_return is_injury_start total_injuries_current_season player_age  \
# 0                NaN           False                             0       39.0
# 1                NaN           False                             0       39.0
# 2                NaN           False                             0       39.0
# 3                NaN           False                             0       39.0
# 4                NaN           False                             0       39.0
#
#   rest_days_since_last_play     surface  _merge
# 0                       NaN  matrixturf    both
# 1                       7.0       grass    both
# 2                       7.0       grass    both
# 3                       7.0       grass    both
# 4                       7.0       grass    both
#
# [5 rows x 33 columns]

# %%
season_change = surf["season"] != surf.groupby("gsis_id")["season"].shift()
surf.loc[season_change, "rest_days_since_last_play"] = None

# %%
# re-injury predictors: age, weeks since return, prior injuries in season, position, rest since last game, surface, snaps (just raw for now)
# could also maybe include last_injury_duration, last_injury_type

surf["injured_after_this_week"] = (
    surf.groupby(by=["gsis_id", "season"])["is_injury_start"].shift(-1).fillna(False)
)
# Out:
# /var/folders/pw/q_xxgr9s6zg0hgq5mx3qxw9h0000gn/T/ipykernel_86182/3293970189.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   surf.groupby(by=["gsis_id", "season"])["is_injury_start"].shift(-1).fillna(False)

# %%
surf.loc[
    (surf["display_name"] == "Kadarius Toney") & (surf["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 200949      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200950      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200951      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200952      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200953      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200954      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200955      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200956      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200957      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200958      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200959      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200960      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200961      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200962      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200963      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200964      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200965      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200966      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200967      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200968      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200969      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... is_return_week  \
# 200949  2022.0   1.0       WR               WR  ...          False
# 200950  2022.0   2.0       WR               WR  ...          False
# 200951  2022.0   3.0       WR               WR  ...          False
# 200952  2022.0   4.0       WR               WR  ...          False
# 200953  2022.0   5.0       WR               WR  ...          False
# 200954  2022.0   6.0       WR               WR  ...          False
# 200955  2022.0   7.0       WR               WR  ...          False
# 200956  2022.0   8.0       WR               WR  ...          False
# 200957  2022.0   9.0       WR               WR  ...           True
# 200958  2022.0  10.0       WR               WR  ...          False
# 200959  2022.0  11.0       WR               WR  ...          False
# 200960  2022.0  12.0       WR               WR  ...          False
# 200961  2022.0  13.0       WR               WR  ...          False
# 200962  2022.0  14.0       WR               WR  ...          False
# 200963  2022.0  15.0       WR               WR  ...           True
# 200964  2022.0  16.0       WR               WR  ...          False
# 200965  2022.0  17.0       WR               WR  ...          False
# 200966  2022.0  18.0       WR               WR  ...          False
# 200967  2022.0  20.0       WR               WR  ...          False
# 200968  2022.0  21.0       WR               WR  ...          False
# 200969  2022.0  22.0       WR               WR  ...          False
#
#        return_week  weeks_since_return is_injury_start  \
# 200949         NaN                 NaN           False
# 200950         NaN                 NaN           False
# 200951         NaN                 NaN            True
# 200952         NaN                 NaN           False
# 200953         NaN                 NaN           False
# 200954         NaN                 NaN           False
# 200955         NaN                 NaN           False
# 200956         NaN                 NaN           False
# 200957         9.0                 0.0           False
# 200958         9.0                 1.0           False
# 200959         9.0                 2.0           False
# 200960         NaN                 NaN            True
# 200961         NaN                 NaN           False
# 200962         NaN                 NaN           False
# 200963        15.0                 0.0           False
# 200964        15.0                 1.0           False
# 200965        15.0                 2.0           False
# 200966        15.0                 3.0           False
# 200967        15.0                 5.0           False
# 200968        15.0                 6.0           False
# 200969        15.0                 7.0           False
#
#        total_injuries_current_season player_age rest_days_since_last_play  \
# 200949                             0       23.0                       NaN
# 200950                             0       23.0                       7.0
# 200951                             0       23.0                       NaN
# 200952                             1       23.0                       NaN
# 200953                             1       23.0                       NaN
# 200954                             1       23.0                       NaN
# 200955                             1       23.0                       NaN
# 200956                             1       23.0                       NaN
# 200957                             1       23.0                      49.0
# 200958                             1       23.0                       7.0
# 200959                             1       23.0                       7.0
# 200960                             1       23.0                       NaN
# 200961                             2       23.0                       NaN
# 200962                             2       23.0                       NaN
# 200963                             2       23.0                      28.0
# 200964                             2       23.0                       6.0
# 200965                             2       23.0                       8.0
# 200966                             2       23.0                       6.0
# 200967                             2       23.0                      14.0
# 200968                             2       24.0                       8.0
# 200969                             2       24.0                      14.0
#
#            surface     _merge  injured_after_this_week
# 200949       grass       both                    False
# 200950   fieldturf       both                     True
# 200951         NaN  left_only                    False
# 200952         NaN  left_only                    False
# 200953         NaN  left_only                    False
# 200954         NaN  left_only                    False
# 200955         NaN  left_only                    False
# 200956         NaN  left_only                    False
# 200957       grass       both                    False
# 200958       grass       both                    False
# 200959  matrixturf       both                     True
# 200960         NaN  left_only                    False
# 200961         NaN  left_only                    False
# 200962         NaN  left_only                    False
# 200963   astroturf       both                    False
# 200964       grass       both                    False
# 200965       grass       both                    False
# 200966       grass       both                    False
# 200967       grass       both                    False
# 200968       grass       both                    False
# 200969       grass       both                    False
#
# [21 rows x 34 columns]

# %%
surf["most_recent_injury"] = surf.groupby(by=["gsis_id", "season"])[
    "report_primary_injury"
].ffill()

# %%
surf.loc[
    (surf["display_name"] == "Kadarius Toney") & (surf["season"] == 2022)
].sort_values("week")
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 200949      199615  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200950      199616  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200951      199617  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200952      199618  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200953      199619  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200954      199620  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200955      199621  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200956      199622  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200957      199623  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200958      199624  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200959      199625  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200960      199626  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200961      199627  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200962      199628  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200963      199629  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200964      199630  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200965      199631  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200966      199632  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200967      199633  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200968      199634  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
# 200969      199635  00-0036913  Kadarius Toney  1999-01-27    72.0   193.0
#
#         season  week position position_group_y  ... return_week  \
# 200949  2022.0   1.0       WR               WR  ...         NaN
# 200950  2022.0   2.0       WR               WR  ...         NaN
# 200951  2022.0   3.0       WR               WR  ...         NaN
# 200952  2022.0   4.0       WR               WR  ...         NaN
# 200953  2022.0   5.0       WR               WR  ...         NaN
# 200954  2022.0   6.0       WR               WR  ...         NaN
# 200955  2022.0   7.0       WR               WR  ...         NaN
# 200956  2022.0   8.0       WR               WR  ...         NaN
# 200957  2022.0   9.0       WR               WR  ...         9.0
# 200958  2022.0  10.0       WR               WR  ...         9.0
# 200959  2022.0  11.0       WR               WR  ...         9.0
# 200960  2022.0  12.0       WR               WR  ...         NaN
# 200961  2022.0  13.0       WR               WR  ...         NaN
# 200962  2022.0  14.0       WR               WR  ...         NaN
# 200963  2022.0  15.0       WR               WR  ...        15.0
# 200964  2022.0  16.0       WR               WR  ...        15.0
# 200965  2022.0  17.0       WR               WR  ...        15.0
# 200966  2022.0  18.0       WR               WR  ...        15.0
# 200967  2022.0  20.0       WR               WR  ...        15.0
# 200968  2022.0  21.0       WR               WR  ...        15.0
# 200969  2022.0  22.0       WR               WR  ...        15.0
#
#        weeks_since_return  is_injury_start total_injuries_current_season  \
# 200949                NaN            False                             0
# 200950                NaN            False                             0
# 200951                NaN             True                             0
# 200952                NaN            False                             1
# 200953                NaN            False                             1
# 200954                NaN            False                             1
# 200955                NaN            False                             1
# 200956                NaN            False                             1
# 200957                0.0            False                             1
# 200958                1.0            False                             1
# 200959                2.0            False                             1
# 200960                NaN             True                             1
# 200961                NaN            False                             2
# 200962                NaN            False                             2
# 200963                0.0            False                             2
# 200964                1.0            False                             2
# 200965                2.0            False                             2
# 200966                3.0            False                             2
# 200967                5.0            False                             2
# 200968                6.0            False                             2
# 200969                7.0            False                             2
#
#        player_age rest_days_since_last_play     surface     _merge  \
# 200949       23.0                       NaN       grass       both
# 200950       23.0                       7.0   fieldturf       both
# 200951       23.0                       NaN         NaN  left_only
# 200952       23.0                       NaN         NaN  left_only
# 200953       23.0                       NaN         NaN  left_only
# 200954       23.0                       NaN         NaN  left_only
# 200955       23.0                       NaN         NaN  left_only
# 200956       23.0                       NaN         NaN  left_only
# 200957       23.0                      49.0       grass       both
# 200958       23.0                       7.0       grass       both
# 200959       23.0                       7.0  matrixturf       both
# 200960       23.0                       NaN         NaN  left_only
# 200961       23.0                       NaN         NaN  left_only
# 200962       23.0                       NaN         NaN  left_only
# 200963       23.0                      28.0   astroturf       both
# 200964       23.0                       6.0       grass       both
# 200965       23.0                       8.0       grass       both
# 200966       23.0                       6.0       grass       both
# 200967       23.0                      14.0       grass       both
# 200968       24.0                       8.0       grass       both
# 200969       24.0                      14.0       grass       both
#
#        injured_after_this_week  most_recent_injury
# 200949                   False                 NaN
# 200950                    True           Hamstring
# 200951                   False           Hamstring
# 200952                   False           Hamstring
# 200953                   False           Hamstring
# 200954                   False           Hamstring
# 200955                   False           Hamstring
# 200956                   False           Hamstring
# 200957                   False           Hamstring
# 200958                   False           Hamstring
# 200959                    True           Hamstring
# 200960                   False           Hamstring
# 200961                   False           Hamstring
# 200962                   False           Hamstring
# 200963                   False           Hamstring
# 200964                   False           Hamstring
# 200965                   False           Hamstring
# 200966                   False           Hamstring
# 200967                   False           Hamstring
# 200968                   False           Hamstring
# 200969                   False           Hamstring
#
# [21 rows x 35 columns]

# %%
# normalize the injury string
import re


# combine categories
def normalize_injury(text):
    if text is None or str(text).strip() == "" or text == "None" or text == "nan":
        return "None"

    t = text.lower()

    # 1. Knee
    if (
        "knee" in t
        or "acl" in t
        or "pcl" in t
        or "mcl" in t
        or "meniscus" in t
        or "patella" in t
    ):
        return "Knee"

    # 2. Ankle / Foot
    if "ankle" in t or "foot" in t or "toe" in t or "achilles" in t or "heel" in t:
        return "Ankle/Foot"

    # 3. Hamstring
    if "hamstring" in t or "hammie" in t:
        return "Hamstring"

    # 4. Quad / Thigh / Groin
    if "quad" in t or "quadricep" in t or "thigh" in t or "groin" in t:
        return "Quad/Thigh/Groin"

    # 5. Shoulder
    if "shoulder" in t or "rotator" in t or "ac joint" in t or "labrum" in t:
        return "Shoulder"

    # 6. Hip / Glute
    if "hip" in t or "glute" in t or "hip flexor" in t:
        return "Hip/Glute"

    # 7. Back
    if "back" in t or "lumbar" in t:
        return "Back"

    # 8. Neck
    if "neck" in t or "cervical" in t:
        return "Neck"

    # 9. Arm
    if "arm" in t or "bicep" in t or "tricep" in t or "forearm" in t:
        return "Arm"

    # 10. Wrist / Hand
    if "wrist" in t or "hand" in t or "finger" in t or "thumb" in t:
        return "Wrist/Hand"

    # 11. Chest / Rib
    if "chest" in t or "rib" in t or "sternum" in t:
        return "Chest/Rib"

    # 12. Abdomen / Core
    if "abdomen" in t or "abdominal" in t or "oblique" in t or "stomach" in t:
        return "Abdomen/Core"

    # 13. Concussion / Head
    if "concussion" in t or "head" in t or "migraine" in t:
        return "Head/Concussion"

    # 14. Illness / Non injury
    if (
        "illness" in t
        or "flu" in t
        or "covid" in t
        or "non-injury" in t
        or "personal" in t
        or "rest" in t
    ):
        return "Illness/OtherNonInjury"

    # 15. Suspension
    if "susp" in t:
        return "None"

    # 16. Fallback
    return "Other"


surf["most_recent_injury"] = (
    surf["most_recent_injury"].astype(str).apply(normalize_injury)
)

# %%
surf["most_recent_injury"].value_counts()
# Out:
# most_recent_injury
# None                      133634
# Ankle/Foot                 18198
# Knee                       14016
# Hamstring                  10475
# Quad/Thigh/Groin            7866
# Other                       7013
# Shoulder                    6476
# Head/Concussion             6126
# Illness/OtherNonInjury      4196
# Back                        3560
# Hip/Glute                   3013
# Wrist/Hand                  2778
# Chest/Rib                   2309
# Neck                        1736
# Abdomen/Core                1070
# Arm                          455
# Name: count, dtype: int64

# %%
len(surf)
# Out:
# 222921

# %%
# I think we can get total offensive/defensive snaps and snaps the player played in from this with some finagling
# but can try that later if we have time?? for now I just left snap count as a feature
pbp = nfl.load_pbp().to_pandas()

# %%
for i in pbp.columns:
    print(i)
# Out:
# play_id
# game_id
# old_game_id
# home_team
# away_team
# season_type
# week
# posteam
# posteam_type
# defteam
# side_of_field
# yardline_100
# game_date
# quarter_seconds_remaining
# half_seconds_remaining
# game_seconds_remaining
# game_half
# quarter_end
# drive
# sp
# qtr
# down
# goal_to_go
# time
# yrdln
# ydstogo
# ydsnet
# desc
# play_type
# yards_gained
# shotgun
# no_huddle
# qb_dropback
# qb_kneel
# qb_spike
# qb_scramble
# pass_length
# pass_location
# air_yards
# yards_after_catch
# run_location
# run_gap
# field_goal_result
# kick_distance
# extra_point_result
# two_point_conv_result
# home_timeouts_remaining
# away_timeouts_remaining
# timeout
# timeout_team
# td_team
# td_player_name
# td_player_id
# posteam_timeouts_remaining
# defteam_timeouts_remaining
# total_home_score
# total_away_score
# posteam_score
# defteam_score
# score_differential
# posteam_score_post
# defteam_score_post
# score_differential_post
# no_score_prob
# opp_fg_prob
# opp_safety_prob
# opp_td_prob
# fg_prob
# safety_prob
# td_prob
# extra_point_prob
# two_point_conversion_prob
# ep
# epa
# total_home_epa
# total_away_epa
# total_home_rush_epa
# total_away_rush_epa
# total_home_pass_epa
# total_away_pass_epa
# air_epa
# yac_epa
# comp_air_epa
# comp_yac_epa
# total_home_comp_air_epa
# total_away_comp_air_epa
# total_home_comp_yac_epa
# total_away_comp_yac_epa
# total_home_raw_air_epa
# total_away_raw_air_epa
# total_home_raw_yac_epa
# total_away_raw_yac_epa
# wp
# def_wp
# home_wp
# away_wp
# wpa
# vegas_wpa
# vegas_home_wpa
# home_wp_post
# away_wp_post
# vegas_wp
# vegas_home_wp
# total_home_rush_wpa
# total_away_rush_wpa
# total_home_pass_wpa
# total_away_pass_wpa
# air_wpa
# yac_wpa
# comp_air_wpa
# comp_yac_wpa
# total_home_comp_air_wpa
# total_away_comp_air_wpa
# total_home_comp_yac_wpa
# total_away_comp_yac_wpa
# total_home_raw_air_wpa
# total_away_raw_air_wpa
# total_home_raw_yac_wpa
# total_away_raw_yac_wpa
# punt_blocked
# first_down_rush
# first_down_pass
# first_down_penalty
# third_down_converted
# third_down_failed
# fourth_down_converted
# fourth_down_failed
# incomplete_pass
# touchback
# interception
# punt_inside_twenty
# punt_in_endzone
# punt_out_of_bounds
# punt_downed
# punt_fair_catch
# kickoff_inside_twenty
# kickoff_in_endzone
# kickoff_out_of_bounds
# kickoff_downed
# kickoff_fair_catch
# fumble_forced
# fumble_not_forced
# fumble_out_of_bounds
# solo_tackle
# safety
# penalty
# tackled_for_loss
# fumble_lost
# own_kickoff_recovery
# own_kickoff_recovery_td
# qb_hit
# rush_attempt
# pass_attempt
# sack
# touchdown
# pass_touchdown
# rush_touchdown
# return_touchdown
# extra_point_attempt
# two_point_attempt
# field_goal_attempt
# kickoff_attempt
# punt_attempt
# fumble
# complete_pass
# assist_tackle
# lateral_reception
# lateral_rush
# lateral_return
# lateral_recovery
# passer_player_id
# passer_player_name
# passing_yards
# receiver_player_id
# receiver_player_name
# receiving_yards
# rusher_player_id
# rusher_player_name
# rushing_yards
# lateral_receiver_player_id
# lateral_receiver_player_name
# lateral_receiving_yards
# lateral_rusher_player_id
# lateral_rusher_player_name
# lateral_rushing_yards
# lateral_sack_player_id
# lateral_sack_player_name
# interception_player_id
# interception_player_name
# lateral_interception_player_id
# lateral_interception_player_name
# punt_returner_player_id
# punt_returner_player_name
# lateral_punt_returner_player_id
# lateral_punt_returner_player_name
# kickoff_returner_player_name
# kickoff_returner_player_id
# lateral_kickoff_returner_player_id
# lateral_kickoff_returner_player_name
# punter_player_id
# punter_player_name
# kicker_player_name
# kicker_player_id
# own_kickoff_recovery_player_id
# own_kickoff_recovery_player_name
# blocked_player_id
# blocked_player_name
# tackle_for_loss_1_player_id
# tackle_for_loss_1_player_name
# tackle_for_loss_2_player_id
# tackle_for_loss_2_player_name
# qb_hit_1_player_id
# qb_hit_1_player_name
# qb_hit_2_player_id
# qb_hit_2_player_name
# forced_fumble_player_1_team
# forced_fumble_player_1_player_id
# forced_fumble_player_1_player_name
# forced_fumble_player_2_team
# forced_fumble_player_2_player_id
# forced_fumble_player_2_player_name
# solo_tackle_1_team
# solo_tackle_2_team
# solo_tackle_1_player_id
# solo_tackle_2_player_id
# solo_tackle_1_player_name
# solo_tackle_2_player_name
# assist_tackle_1_player_id
# assist_tackle_1_player_name
# assist_tackle_1_team
# assist_tackle_2_player_id
# assist_tackle_2_player_name
# assist_tackle_2_team
# assist_tackle_3_player_id
# assist_tackle_3_player_name
# assist_tackle_3_team
# assist_tackle_4_player_id
# assist_tackle_4_player_name
# assist_tackle_4_team
# tackle_with_assist
# tackle_with_assist_1_player_id
# tackle_with_assist_1_player_name
# tackle_with_assist_1_team
# tackle_with_assist_2_player_id
# tackle_with_assist_2_player_name
# tackle_with_assist_2_team
# pass_defense_1_player_id
# pass_defense_1_player_name
# pass_defense_2_player_id
# pass_defense_2_player_name
# fumbled_1_team
# fumbled_1_player_id
# fumbled_1_player_name
# fumbled_2_player_id
# fumbled_2_player_name
# fumbled_2_team
# fumble_recovery_1_team
# fumble_recovery_1_yards
# fumble_recovery_1_player_id
# fumble_recovery_1_player_name
# fumble_recovery_2_team
# fumble_recovery_2_yards
# fumble_recovery_2_player_id
# fumble_recovery_2_player_name
# sack_player_id
# sack_player_name
# half_sack_1_player_id
# half_sack_1_player_name
# half_sack_2_player_id
# half_sack_2_player_name
# return_team
# return_yards
# penalty_team
# penalty_player_id
# penalty_player_name
# penalty_yards
# replay_or_challenge
# replay_or_challenge_result
# penalty_type
# defensive_two_point_attempt
# defensive_two_point_conv
# defensive_extra_point_attempt
# defensive_extra_point_conv
# safety_player_name
# safety_player_id
# season
# cp
# cpoe
# series
# series_success
# series_result
# order_sequence
# start_time
# time_of_day
# stadium
# weather
# nfl_api_id
# play_clock
# play_deleted
# play_type_nfl
# special_teams_play
# st_play_type
# end_clock_time
# end_yard_line
# fixed_drive
# fixed_drive_result
# drive_real_start_time
# drive_play_count
# drive_time_of_possession
# drive_first_downs
# drive_inside20
# drive_ended_with_score
# drive_quarter_start
# drive_quarter_end
# drive_yards_penalized
# drive_start_transition
# drive_end_transition
# drive_game_clock_start
# drive_game_clock_end
# drive_start_yard_line
# drive_end_yard_line
# drive_play_id_started
# drive_play_id_ended
# away_score
# home_score
# location
# result
# total
# spread_line
# total_line
# div_game
# roof
# surface
# temp
# wind
# home_coach
# away_coach
# stadium_id
# game_stadium
# aborted_play
# success
# passer
# passer_jersey_number
# rusher
# rusher_jersey_number
# receiver
# receiver_jersey_number
# pass
# rush
# first_down
# special
# play
# passer_id
# rusher_id
# receiver_id
# name
# jersey_number
# id
# fantasy_player_name
# fantasy_player_id
# fantasy
# fantasy_id
# out_of_bounds
# home_opening_kickoff
# qb_epa
# xyac_epa
# xyac_mean_yardage
# xyac_median_yardage
# xyac_success
# xyac_fd
# xpass
# pass_oe

# %%
# final re-injury dataset: player-weeks where player plays and had a previous injury this season
play_filtered = surf.loc[
    (surf["played"]) & (surf["total_injuries_current_season"] >= 1)
]

# %%
# re-injury label: 1 if player had previous injury, plays that week, and is injured the following week
play_filtered["reinjured_next_week"] = (
    (play_filtered["total_injuries_current_season"] >= 1)
    & (play_filtered["injured_after_this_week"])
    & play_filtered["played"]
).astype(int)

# %%
play_filtered = play_filtered[
    [
        "reinjured_next_week",  # outcome
        "player_age",
        "position_group_y",
        "season",  # not a predictor but need for the time-based CV
        # "week",
        "rest_days_since_last_play",
        "surface",
        "total_snaps",
        "weeks_since_return",  # wouldn't use these last three for injury risk
        "total_injuries_current_season",
        "most_recent_injury",
        "gsis_id",  # added for future use in mixed effects
    ]
]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score

import xgboost as xgb
import shap

# %%
play_filtered["surface"] = play_filtered["surface"].astype("category")
play_filtered["most_recent_injury"] = play_filtered["most_recent_injury"].astype(
    "category"
)
play_filtered["position_group_y"] = play_filtered["position_group_y"].astype("category")
# play_filtered["week"] = play_filtered["week"].astype("category")

# %%
play_filtered.head()
# Out:
#      reinjured_next_week  player_age position_group_y  season  \
# 74                     0        43.0             SPEC  2018.0
# 120                    0        39.0               QB  2015.0
# 121                    0        39.0               QB  2015.0
# 122                    0        39.0               QB  2015.0
# 123                    0        39.0               QB  2015.0
#
#      rest_days_since_last_play surface  total_snaps  weeks_since_return  \
# 74                        14.0   grass          6.0                 0.0
# 120                       49.0   grass         29.0                 0.0
# 121                       14.0   grass         74.0                 2.0
# 122                        7.0   grass         68.0                 3.0
# 123                       14.0   grass         60.0                 4.0
#
#      total_injuries_current_season most_recent_injury     gsis_id
# 74                               1          Hip/Glute  00-0004091
# 120                              1         Ankle/Foot  00-0010346
# 121                              1         Ankle/Foot  00-0010346
# 122                              1         Ankle/Foot  00-0010346
# 123                              1         Ankle/Foot  00-0010346

# %%
play_filtered["reinjured_next_week"].value_counts() / len(play_filtered)
# Out:
# reinjured_next_week
# 0    0.93532
# 1    0.06468
# Name: count, dtype: float64

# %% [markdown]
# ## Re-Injury Risk Model

# %%
from sklearn.metrics import (
    average_precision_score,
    roc_auc_score,
    accuracy_score,
    confusion_matrix,
)

# %%
seasons = np.arange(2014, 2025)
all_shap = []
all_X = []
precs = []
rocs = []

for season in range(1, len(seasons)):
    test_season = seasons[season]
    train_seasons = seasons[:season]
    print(train_seasons, test_season)
    train_df = play_filtered.loc[play_filtered["season"].isin(train_seasons)]
    test_df = play_filtered.loc[play_filtered["season"] == test_season]
    model = xgb.XGBClassifier(
        n_estimators=100,
        objective="binary:logistic",
        enable_categorical=True,
        random_state=42,
    )
    X_train = train_df.drop(["reinjured_next_week", "season", "gsis_id"], axis=1)
    y_train = train_df["reinjured_next_week"]
    X_test = test_df.drop(["reinjured_next_week", "season", "gsis_id"], axis=1)
    y_test = test_df["reinjured_next_week"]
    model.fit(X_train, y_train)
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= 0.5).astype(int)
    precs.append(average_precision_score(y_test, y_prob))
    rocs.append(roc_auc_score(y_test, y_prob))
    print(f"AP: {average_precision_score(y_test, y_prob)}")
    print(f"ROC AUC: {roc_auc_score(y_test, y_prob)}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"CM: {confusion_matrix(y_test, y_pred)}")

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_test)
    # handle binary case (list) vs array
    if isinstance(shap_values, list):
        shap_values_fold = shap_values[1]
    else:
        shap_values_fold = shap_values

    all_shap.append(shap_values_fold)
    all_X.append(X_test.values)  # or X_test.copy() if you want a DataFrame

# after the loop
shap_all = np.vstack(all_shap)
X_all = np.vstack(all_X)
feature_names = X_test.columns
print(f"Overall average AP: {np.mean(np.array(precs))}")
print(f"Overall average AUC: {np.mean(np.array(rocs))}")
# Out:
# [2014] 2015
# AP: 0.1337638968580303
# ROC AUC: 0.6027073177449117
# Accuracy: 0.9064404982772329
# CM: [[3401   57]
#  [ 296   19]]
# [2014 2015] 2016
# AP: 0.10441582650470535
# ROC AUC: 0.6246550643193498
# Accuracy: 0.9178505250154416
# CM: [[2964   57]
#  [ 209    8]]
# [2014 2015 2016] 2017
# AP: 0.10908734233291975
# ROC AUC: 0.5941403454827401
# Accuracy: 0.930111038536904
# CM: [[2836   43]
#  [ 171   12]]
# [2014 2015 2016 2017] 2018
# AP: 0.11653316468542982
# ROC AUC: 0.6494015484410963
# Accuracy: 0.928042328042328
# CM: [[2627   28]
#  [ 176    4]]
# [2014 2015 2016 2017 2018] 2019
# AP: 0.08538656152951252
# ROC AUC: 0.6221083484940367
# Accuracy: 0.9363636363636364
# CM: [[2881   29]
#  [ 167    3]]
# [2014 2015 2016 2017 2018 2019] 2020
# AP: 0.11455944576695426
# ROC AUC: 0.5955971058575243
# Accuracy: 0.9322239031770045
# CM: [[3077   14]
#  [ 210    4]]
# [2014 2015 2016 2017 2018 2019 2020] 2021
# AP: 0.09594017677507966
# ROC AUC: 0.6159538796321635
# Accuracy: 0.931899641577061
# CM: [[3373   33]
#  [ 214    7]]
# [2014 2015 2016 2017 2018 2019 2020 2021] 2022
# AP: 0.08921274710993621
# ROC AUC: 0.5812734512996854
# Accuracy: 0.9315679077084426
# CM: [[3549   24]
#  [ 237    4]]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022] 2023
# AP: 0.10528048498672204
# ROC AUC: 0.6226231106777183
# Accuracy: 0.9392142327650111
# CM: [[3796   13]
#  [ 233    5]]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022 2023] 2024
# AP: 0.09417461431352257
# ROC AUC: 0.6436125708203179
# Accuracy: 0.9391414141414142
# CM: [[3717   16]
#  [ 225    2]]
# Overall average AP: 0.10483542608628124
# Overall average AUC: 0.6152072742769544

# %%
print(feature_names)
# Out:
# Index(['player_age', 'position_group_y', 'rest_days_since_last_play',
#        'surface', 'total_snaps', 'weeks_since_return',
#        'total_injuries_current_season', 'most_recent_injury'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

shap.summary_plot(
    shap_all,
    X_all,
    feature_names=[
        "Player Age",
        "Position Group",
        "Rest Days Since Last Game",
        "Game Surface",
        "Snap Count",
        "Weeks Since Return",
        "Total Injuries This Season",
        "Category of Most Recent Injury",
    ],
    show=False,
)
plt.title(
    "Contributions of Different Features on Re-Injury Risk Prediction (XGBoost)",
    loc="left",
    x=-0.6,
    pad=20,
)

plt.show()

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

# Plot the feature importance
plot_importance(model)
plt.rcParams["figure.figsize"] = [6, 4]  # Adjust plot size
plt.show()

# %% [markdown]
# ## Injury Risk Model

# %%
first_timers = surf.loc[surf["total_injuries_current_season"] < 1]

# %%
first_timers["injured_after_this_week"].value_counts() / len(first_timers)
# Out:
# injured_after_this_week
# False    0.957893
# True     0.042107
# Name: count, dtype: float64

# %%
# trying with next week injury as outcome bc makes more sense
nextweek = first_timers[
    [
        "player_age",
        "position_group_y",
        "season",  # not a predictor but need for the time-based CV
        # "week",
        "rest_days_since_last_play",
        "surface",
        "total_snaps",
        "injured_after_this_week",  # is this the outcome or should it be missed this game?
        # also could maybe use most recent injury if they were injured last season?
        "gsis_id",
    ]
]

# %%
nextweek["surface"] = nextweek["surface"].astype("category")
# filtered_cols["most_recent_injury"] = filtered_cols["most_recent_injury"].astype(
#    "category"
# )
nextweek["injured_after_this_week"] = nextweek["injured_after_this_week"].astype("int")
nextweek["position_group_y"] = nextweek["position_group_y"].astype("category")

# %%
# trying with outcome variable being next week injured
seasons = np.arange(2014, 2025)
all_shap = []
all_X = []
precs = []
rocs = []
for season in range(1, len(seasons)):
    test_season = seasons[season]
    train_seasons = seasons[:season]
    print(train_seasons, test_season)
    train_df = nextweek.loc[nextweek["season"].isin(train_seasons)]
    test_df = nextweek.loc[nextweek["season"] == test_season]
    model = xgb.XGBClassifier(
        n_estimators=100,
        objective="binary:logistic",
        enable_categorical=True,
        random_state=42,
    )
    X_train = train_df.drop(["injured_after_this_week", "season", "gsis_id"], axis=1)
    y_train = train_df["injured_after_this_week"]
    X_test = test_df.drop(["injured_after_this_week", "season", "gsis_id"], axis=1)
    y_test = test_df["injured_after_this_week"]
    model.fit(X_train, y_train)
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= 0.5).astype(int)
    ap = average_precision_score(y_test, y_prob)
    roc = roc_auc_score(y_test, y_prob)
    precs.append(ap)
    rocs.append(roc)
    print(f"AP: {average_precision_score(y_test, y_prob)}")
    print(f"ROC AUC: {roc_auc_score(y_test, y_prob)}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"CM: {confusion_matrix(y_test, y_pred)}")

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_test)
    # handle binary case (list) vs array
    if isinstance(shap_values, list):
        shap_values_fold = shap_values[1]
    else:
        shap_values_fold = shap_values

    all_shap.append(shap_values_fold)
    all_X.append(X_test.values)  # or X_test.copy() if you want a DataFrame

# after the loop
shap_all = np.vstack(all_shap)
X_all = np.vstack(all_X)
feature_names = X_test.columns

print(f"Overall average AP: {np.mean(np.array(precs))}")
print(f"Overall average AUC: {np.mean(np.array(rocs))}")
# Out:
# [2014] 2015
# AP: 0.08377367822028747
# ROC AUC: 0.668024039810639
# Accuracy: 0.9508267744963536
# CM: [[13159    58]
#  [  623     9]]
# [2014 2015] 2016
# AP: 0.07923881982970987
# ROC AUC: 0.6588554856311705
# Accuracy: 0.9561526589027641
# CM: [[13625    36]
#  [  589     4]]
# [2014 2015 2016] 2017
# AP: 0.07346545591672148
# ROC AUC: 0.6569358133802751
# Accuracy: 0.9596811690468283
# CM: [[14442    21]
#  [  586     6]]
# [2014 2015 2016 2017] 2018
# AP: 0.0712711307082124
# ROC AUC: 0.6389586213153227
# Accuracy: 0.9617587046666228
# CM: [[14608    12]
#  [  569     4]]
# [2014 2015 2016 2017 2018] 2019
# AP: 0.08103705185838499
# ROC AUC: 0.6565342661077265
# Accuracy: 0.958870101986044
# CM: [[14289    10]
#  [  603     2]]
# [2014 2015 2016 2017 2018 2019] 2020
# AP: 0.08096564494987142
# ROC AUC: 0.6436153417560752
# Accuracy: 0.9559961624560281
# CM: [[14946     7]
#  [  681     1]]
# [2014 2015 2016 2017 2018 2019 2020] 2021
# AP: 0.06451022537913402
# ROC AUC: 0.6143055770294298
# Accuracy: 0.9593197932940752
# CM: [[15965     3]
#  [  674     0]]
# [2014 2015 2016 2017 2018 2019 2020 2021] 2022
# AP: 0.08533643625799667
# ROC AUC: 0.6492023559736012
# Accuracy: 0.9562277142505841
# CM: [[15551     7]
#  [  705     3]]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022] 2023
# AP: 0.0743919352405075
# ROC AUC: 0.6300200495653125
# Accuracy: 0.9541429475015812
# CM: [[15083    10]
#  [  715     2]]
# [2014 2015 2016 2017 2018 2019 2020 2021 2022 2023] 2024
# AP: 0.08114002098279768
# ROC AUC: 0.6401105649871015
# Accuracy: 0.9549681840430739
# CM: [[15607     4]
#  [  732     1]]
# Overall average AP: 0.07751303993436234
# Overall average AUC: 0.6456562115556654

# %%
feature_names
# Out:
# Index(['player_age', 'position_group_y', 'rest_days_since_last_play',
#        'surface', 'total_snaps'],
#       dtype='object')

# %%
shap.summary_plot(
    shap_all,
    X_all,
    feature_names=[
        "Player Age",
        "Position Group",
        "Rest Days Since Last Game",
        "Game Surface",
        "Snap Count",
    ],
    show=False,
)
plt.title(
    "Contributions of Different Features on Injury Risk Prediction (XGBoost)",
    loc="left",
    x=-0.45,
    pad=20,
)

plt.show()

# %%
# Plot the feature importance
plot_importance(model)
plt.rcParams["figure.figsize"] = [6, 4]  # Adjust plot size
plt.show()

# %% [markdown]
# ## General EDA

# %%
surf.groupby("most_recent_injury")["total_snaps"].mean()
# Out:
# most_recent_injury
# Abdomen/Core              34.863551
# Ankle/Foot                30.746511
# Arm                       29.191209
# Back                      33.155618
# Chest/Rib                 35.067129
# Hamstring                 30.984821
# Head/Concussion           32.650180
# Hip/Glute                 34.844341
# Illness/OtherNonInjury    32.574118
# Knee                      29.843893
# Neck                      34.137673
# None                      39.694726
# Other                     33.692856
# Quad/Thigh/Groin          34.385838
# Shoulder                  33.422792
# Wrist/Hand                32.950684
# Name: total_snaps, dtype: float64

# %%
surf.groupby("most_recent_injury")["rest_days_since_last_play"].mean()
# Out:
# most_recent_injury
# Abdomen/Core               8.982323
# Ankle/Foot                 5.691900
# Arm                       12.099644
# Back                       9.115519
# Chest/Rib                  8.835127
# Hamstring                  6.963577
# Head/Concussion            7.221398
# Hip/Glute                  7.349377
# Illness/OtherNonInjury     9.997551
# Knee                       6.366663
# Neck                      10.386213
# None                       9.853237
# Other                      9.684697
# Quad/Thigh/Groin           7.759838
# Shoulder                   4.410081
# Wrist/Hand                 3.060731
# Name: rest_days_since_last_play, dtype: float64

# %%
import seaborn as sns

injury_rates = (
    surf.groupby("most_recent_injury")["injured_after_this_week"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

plt.figure(figsize=(10, 6))
sns.barplot(data=injury_rates, x="most_recent_injury", y="injured_after_this_week")
plt.xticks(rotation=45, ha="right")
plt.ylabel("Probability of Injury Next Week")
plt.xlabel("Injury Category")
plt.title("Injury Risk by Injury Category")
plt.show()

# %%
surf["rest_days_since_last_play"].describe()  # why are there negative numbers
# Out:
# count    174411.000000
# mean          8.844947
# std          88.710978
# min       -3759.000000
# 25%           7.000000
# 50%           7.000000
# 75%          10.000000
# max        2170.000000
# Name: rest_days_since_last_play, dtype: float64

# %%
temp = surf.groupby("position_group_y")["injured_after_this_week"].mean().reset_index()

plt.figure(figsize=(9, 5))
sns.barplot(data=temp, x="position_group_y", y="injured_after_this_week")
plt.xlabel("Position")
plt.ylabel("Probability of Injury Next Week")
plt.title("Position vs Injury Risk")
plt.show()

# %%
surf
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 0                0  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 1                1  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 2                2  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 3                3  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 4                4  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# ...            ...         ...             ...         ...     ...     ...
# 222916      221582  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222917      221583  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222918      221584  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222919      221585  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222920      221586  00-0039934  Jude McAtamney  2000-05-09    74.0   205.0
#
#         season  week position position_group_y  ... return_week  \
# 0       2014.0   1.0        K             SPEC  ...         NaN
# 1       2014.0   2.0        K             SPEC  ...         NaN
# 2       2014.0   3.0        K             SPEC  ...         NaN
# 3       2014.0   4.0        K             SPEC  ...         NaN
# 4       2014.0   5.0        K             SPEC  ...         NaN
# ...        ...   ...      ...              ...  ...         ...
# 222916  2024.0  14.0        T               OL  ...        14.0
# 222917  2024.0  15.0        T               OL  ...        14.0
# 222918  2024.0  17.0        T               OL  ...         NaN
# 222919  2024.0  18.0        T               OL  ...         NaN
# 222920  2024.0   9.0        K             SPEC  ...         NaN
#
#        weeks_since_return  is_injury_start total_injuries_current_season  \
# 0                     NaN            False                             0
# 1                     NaN            False                             0
# 2                     NaN            False                             0
# 3                     NaN            False                             0
# 4                     NaN            False                             0
# ...                   ...              ...                           ...
# 222916                0.0            False                             1
# 222917                1.0            False                             1
# 222918                NaN             True                             1
# 222919                NaN            False                             2
# 222920                NaN            False                             0
#
#        player_age rest_days_since_last_play     surface     _merge  \
# 0            39.0                       NaN  matrixturf       both
# 1            39.0                       7.0       grass       both
# 2            39.0                       7.0       grass       both
# 3            39.0                       7.0       grass       both
# 4            39.0                       7.0       grass       both
# ...           ...                       ...         ...        ...
# 222916       22.0                      36.0  matrixturf       both
# 222917       22.0                       6.0       grass       both
# 222918       22.0                       NaN         NaN  left_only
# 222919       22.0                       NaN         NaN  left_only
# 222920       24.0                       NaN   fieldturf       both
#
#        injured_after_this_week  most_recent_injury
# 0                        False                None
# 1                        False                None
# 2                        False                None
# 3                        False                None
# 4                        False                None
# ...                        ...                 ...
# 222916                   False               Other
# 222917                    True               Other
# 222918                   False          Ankle/Foot
# 222919                   False          Ankle/Foot
# 222920                   False                None
#
# [222921 rows x 35 columns]

# %%
temp = surf.groupby("total_snaps")["injured_after_this_week"].mean().reset_index()

plt.figure(figsize=(9, 5))
sns.lineplot(data=temp, x="total_snaps", y="injured_after_this_week")
plt.xlabel("Total Snaps")
plt.ylabel("Probability of Injury Next Week")
plt.title("Snap Count vs Injury Risk")
plt.show()

# %%
temp = surf.groupby("player_age")["injured_after_this_week"].mean().reset_index()

plt.figure(figsize=(9, 5))
sns.lineplot(data=temp, x="player_age", y="injured_after_this_week")
plt.xlabel("Age")
plt.ylabel("Probability of Injury Next Week")
plt.title("Age vs Injury Risk")
plt.show()

# %%
temp = (
    surf.groupby("total_injuries_current_season")["injured_after_this_week"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(9, 5))
sns.barplot(data=temp, x="total_injuries_current_season", y="injured_after_this_week")
plt.xlabel("Injury count this season")
plt.ylabel("Injury Likelihood")
plt.title("Num of Injuries vs Injury Risk")
plt.show()

# %%
temp = (
    surf.groupby("position_group_y")["total_injuries_current_season"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(9, 5))
sns.barplot(data=temp, x="position_group_y", y="total_injuries_current_season")
plt.xlabel("Position")
plt.ylabel("Avge number of injuries in current season")
plt.title("Position vs Avge num of Injuries")
plt.show()

# %%
temp = surf.groupby("player_age")["total_injuries_current_season"].mean().reset_index()

plt.figure(figsize=(9, 5))
sns.barplot(data=temp, x="player_age", y="total_injuries_current_season")
plt.xlabel("Age")
plt.xticks(rotation=45, ha="right")

plt.ylabel("Avge number of injuries in current season")
plt.title("Age vs Num of Injuries")
plt.show()

# %%
temp = surf.groupby("total_snaps")["total_injuries_current_season"].mean().reset_index()

plt.figure(figsize=(9, 5))
sns.lineplot(data=temp, x="total_snaps", y="total_injuries_current_season")
plt.xlabel("Total Snaps")
plt.xticks(rotation=45, ha="right")

plt.ylabel("Avge number of injuries in current season")
plt.title("Total Snaps vs Num of Injuries")
plt.show()

# %%
surf
# Out:
#         Unnamed: 0     gsis_id    display_name  birth_date  height  weight  \
# 0                0  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 1                1  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 2                2  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 3                3  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# 4                4  00-0004091     Phil Dawson  1975-01-23    71.0   200.0
# ...            ...         ...             ...         ...     ...     ...
# 222916      221582  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222917      221583  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222918      221584  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222919      221585  00-0039925    Amarius Mims  2002-10-14    80.0   350.0
# 222920      221586  00-0039934  Jude McAtamney  2000-05-09    74.0   205.0
#
#         season  week position position_group_y  ... return_week  \
# 0       2014.0   1.0        K             SPEC  ...         NaN
# 1       2014.0   2.0        K             SPEC  ...         NaN
# 2       2014.0   3.0        K             SPEC  ...         NaN
# 3       2014.0   4.0        K             SPEC  ...         NaN
# 4       2014.0   5.0        K             SPEC  ...         NaN
# ...        ...   ...      ...              ...  ...         ...
# 222916  2024.0  14.0        T               OL  ...        14.0
# 222917  2024.0  15.0        T               OL  ...        14.0
# 222918  2024.0  17.0        T               OL  ...         NaN
# 222919  2024.0  18.0        T               OL  ...         NaN
# 222920  2024.0   9.0        K             SPEC  ...         NaN
#
#        weeks_since_return  is_injury_start total_injuries_current_season  \
# 0                     NaN            False                             0
# 1                     NaN            False                             0
# 2                     NaN            False                             0
# 3                     NaN            False                             0
# 4                     NaN            False                             0
# ...                   ...              ...                           ...
# 222916                0.0            False                             1
# 222917                1.0            False                             1
# 222918                NaN             True                             1
# 222919                NaN            False                             2
# 222920                NaN            False                             0
#
#        player_age rest_days_since_last_play     surface     _merge  \
# 0            39.0                       NaN  matrixturf       both
# 1            39.0                       7.0       grass       both
# 2            39.0                       7.0       grass       both
# 3            39.0                       7.0       grass       both
# 4            39.0                       7.0       grass       both
# ...           ...                       ...         ...        ...
# 222916       22.0                      36.0  matrixturf       both
# 222917       22.0                       6.0       grass       both
# 222918       22.0                       NaN         NaN  left_only
# 222919       22.0                       NaN         NaN  left_only
# 222920       24.0                       NaN   fieldturf       both
#
#        injured_after_this_week  most_recent_injury
# 0                        False                None
# 1                        False                None
# 2                        False                None
# 3                        False                None
# 4                        False                None
# ...                        ...                 ...
# 222916                   False               Other
# 222917                    True               Other
# 222918                   False          Ankle/Foot
# 222919                   False          Ankle/Foot
# 222920                   False                None
#
# [222921 rows x 35 columns]

# %%
temp = surf.copy()
temp["prev_injury_any"] = temp["total_injuries_current_season"] > 0

# %%
tmp = temp.groupby("prev_injury_any")["injured_after_this_week"].mean().reset_index()

sns.barplot(data=tmp, x="prev_injury_any", y="injured_after_this_week")
plt.xlabel("Had Previous Injury This Season?")
plt.ylabel("Probability of Injury Next Week")
plt.title("Reinjury Risk vs First Injury Risk")
plt.show()

# %%
pivot = surf.pivot_table(
    index="position_group_y",
    columns="most_recent_injury",
    values="injured_after_this_week",
    aggfunc="mean",
)

plt.figure(figsize=(12, 7))
sns.heatmap(pivot, cmap="Reds")
plt.xlabel("Most Recent Injury Category")
plt.ylabel("Position Group")
plt.title("Injury Risk by Position + Injury Category")
plt.show()
